# %%
import random

def diffie_hellman(prime, primitive_root):
    xa = random.randint(1, prime-1)
    ya = pow(primitive_root, xa, prime)
    print(f"A's private key : {xa}, public key = {ya}")

    xb = random.randint(1, prime - 1)
    yb = pow(primitive_root,xb,prime)
    print(f"B's primitive root = {xb}, public key = {yb}")

    ka = pow(yb,xa,prime)
    kb = pow(ya,xb,prime)

    print(f"Shared key at A's end = {ka}, at B's end = {kb}")

prime = 253
primitive_root = 3
diffie_hellman(prime,primitive_root)
# Out:
# A's private key : 236, public key = 36
# B's primitive root = 126, public key = 36
# Shared key at A's end = 234, at B's end = 234
